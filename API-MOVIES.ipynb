# %%
import omdb
from omdb import OMDBClient
#https://pypi.org/project/omdb/

# %%
# https://en.wikipedia.org/wiki/List_of_Academy_Award-winning_films

# %%
omdb.set_default('apikey', "97d852c1")

# %%
result = omdb.get(title="Sunset Boulevard", fullplot=True, tomatoes=True)

import pandas as pd
df = pd.DataFrame(result)

from IPython.display import Image
from IPython.core.display import HTML 
Image(url= df["poster"][0])
# Out:
# <img src="https://m.media-amazon.com/images/M/MV5BMTg1NzE0MzM5OF5BMl5BanBnXkFtZTYwMTMyNjk5._V1_SX300.jpg"/>

# %%
df.head(1).T
# Out:
#                                                                      0
# title                                                     Pretty Woman
# year                                                              1990
# rated                                                                R
# released                                                   23 Mar 1990
# runtime                                                        119 min
# genre                                                  Comedy, Romance
# director                                                Garry Marshall
# writer                                                     J.F. Lawton
# actors               Richard Gere, Julia Roberts, Ralph Bellamy, Ja...
# plot                 Because of his extreme wealth and suave good l...
# language                                                       English
# country                                                            USA
# ...

# %%
df["awards"]
# Out:
# 0    Nominated for 1 Oscar. Another 8 wins & 10 nom...
# 1    Nominated for 1 Oscar. Another 8 wins & 10 nom...
# 2    Nominated for 1 Oscar. Another 8 wins & 10 nom...
# Name: awards, dtype: object

# %%
df["poster"][0]
# Out:
# 'https://m.media-amazon.com/images/M/MV5BNjk2ODQzNDYxNV5BMl5BanBnXkFtZTgwMTcyNDg4NjE@._V1_SX300.jpg'

# %%
import pandas as pd
OSCARS = pd.read_csv('oscar_movies.csv')
OSCARS.head(10)
# Out:
#                          Film  Year Awards Nominations
# 0                  Green Book  2018      3           5
# 1           Bohemian Rhapsody  2018      4           5
# 2                        Roma  2018      3          10
# 3               Black Panther  2018      3           7
# 4               The Favourite  2018      1          10
# 5              A Star Is Born  2018      1           8
# 6                        Vice  2018      1           8
# 7              BlacKkKlansman  2018      1           6
# 8                   First Man  2018      1           4
# 9  If Beale Street Could Talk  2018      1           3

# %%
OSCARS.shape
# Out:
# (1299, 4)

# %%
# your code

elapsed_time
# Out:
# 0.0

# %%
import time

start_time = time.time()

DF = pd.DataFrame()
for index, row in OSCARS.iterrows():
    moviename = row['Film']
    result = omdb.get(title=moviename, fullplot=True, tomatoes=True)
    df = pd.DataFrame(result)
    DF = DF.append(df.head(1))
    elapsed_time = time.time() - start_time
    print(index, round(elapsed_time,2), moviename)
# Out:
# 0 0.04 Green Book
# 1 0.07 Bohemian Rhapsody
# 2 0.09 Roma
# 3 0.14 Black Panther
# 4 0.21 The Favourite
# 5 0.28 A Star Is Born
# 6 0.35 Vice
# 7 0.38 BlacKkKlansman
# 8 0.41 First Man
# 9 0.44 If Beale Street Could Talk
# 10 0.46 Bao
# 11 0.51 Free Solo
# 12 0.53 Period. End of Sentence.
# 13 0.55 Skin
# 14 0.58 Spider-Man: Into the Spider-Verse
# 15 0.6 The Shape of Water
# 16 0.62 Dunkirk
# 17 0.65 Three Billboards Outside Ebbing, Missouri
# 18 0.67 Darkest Hour
# 19 0.69 Blade Runner 2049
# 20 0.72 Coco
# 21 0.74 Phantom Thread
# 22 0.83 Call Me by Your Name
# 23 0.86 Get Out
# 24 0.89 I, Tonya
# 25 0.91 Dear Basketball
# 26 0.94 A Fantastic Woman
# 27 0.97 Heaven Is a Traffic Jam on the 405
# 28 0.99 Icarus
# 29 1.02 The Silent Child
# 30 1.04 Flesh and Sand (Carne y arena)
# 31 1.08 Moonlight
# 32 1.1 La La Land
# 33 1.13 Hacksaw Ridge
# 34 1.15 Manchester by the Sea
# 35 1.17 Arrival
# 36 1.19 Fences
# 37 1.22 Fantastic Beasts and Where to Find Them
# 38 1.24 The Jungle Book
# ...

# %%
# http://www.omdbapi.com/?t=The+Hours&page=1&plot=full&tomatoes=true&apikey=97d852c1

# %%
DF
# Out:
#                                                actors  \
# 0   Viggo Mortensen, Mahershala Ali, Linda Cardell...
# 0     Rami Malek, Lucy Boynton, Gwilym Lee, Ben Hardy
# 0   Yalitza Aparicio, Marina de Tavira, Diego Cort...
# 0   Chadwick Boseman, Michael B. Jordan, Lupita Ny...
# 0   Olivia Colman, Rachel Weisz, Emma Delves, Faye...
# 0   Lady Gaga, Bradley Cooper, Sam Elliott, Andrew...
# 0   Christian Bale, Amy Adams, Steve Carell, Sam R...
# 0   Alec Baldwin, John David Washington, Isiah Whi...
# 0   Ryan Gosling, Claire Foy, Jason Clarke, Kyle C...
# 0   KiKi Layne, Stephan James, Regina King, Teyona...
# 0                Sindy Lau, Sharmaine Yeoh, Tim Zhang
# 0   Alex Honnold, Tommy Caldwell, Jimmy Chin, Chey...
# 0          Ajeya, Anita, Gouri Choudari, Shabana Khan
# 0   Jamie Bell, Danielle Macdonald, Daniel Henshal...
# 0   Shameik Moore, Jake Johnson, Hailee Steinfeld,...
# 0   Sally Hawkins, Michael Shannon, Richard Jenkin...
# ...

# %%
import numpy as np
DF = DF.replace('N/A',np.NaN)
DF = DF.dropna(axis = "columns")
DF.T
# Out:
#                                                              0  \
# title                                               Green Book
# year                                                      2018
# rated                                                    PG-13
# released                                           16 Nov 2018
# runtime                                                130 min
# genre                          Biography, Comedy, Drama, Music
# director                                        Peter Farrelly
# writer       Nick Vallelonga, Brian Hayes Currie, Peter Far...
# actors       Viggo Mortensen, Mahershala Ali, Linda Cardell...
# plot         A working-class Italian-American bouncer becom...
# language                     English, Italian, Russian, German
# country                                                    USA
# poster       https://m.media-amazon.com/images/M/MV5BYzIzYm...
# ratings      {'source': 'Internet Movie Database', 'value':...
# ...

# %%
DF.to_csv("API_Movies.csv")

# %%
mongodb+srv://AdminUser:UserMovie1@filmrecomandercluster-dtwmc.mongodb.net/test?retryWrites=true&w=majority
# Out:
#   File "<ipython-input-18-07ea23e5c3df>", line 1
#     mongodb+srv://AdminUser:UserMovie1@filmrecomandercluster-dtwmc.mongodb.net/test?retryWrites=true&w=majority
#                  ^
# SyntaxError: invalid syntax

# %%
import pymongo
try:
    #create a credentials.txt file in this folder:
    #first line: Database username (not account username)
    #second line: Database username password (not account password)
    #third line: Databse url with port (you can find it in the database dashboard)
    #fourth line: Database name

    conn=pymongo.MongoClient("mongodb+srv://AdminUser:UserMovie1@filmrecomandercluster-dtwmc.mongodb.net/test?retryWrites=true&w=majority")
    print ("Connected successfully!!!")
    
except pymongo.errors.ConnectionFailure as e:
    print ("Could not connect to MongoDB: %s" % e) 
conn
# Out:
# Connected successfully!!!
# MongoClient(host=['filmrecomandercluster-shard-00-02-dtwmc.mongodb.net:27017', 'filmrecomandercluster-shard-00-01-dtwmc.mongodb.net:27017', 'filmrecomandercluster-shard-00-00-dtwmc.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='FilmRecomanderCluster-shard-0', ssl=True)

# %%
db = conn["films"]

# %%
db.film.insert({"name": str(DF["title"].head(1)), "year": int(DF["year"].head(1))})
# Out:
# C:\Users\xavie\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   """Entry point for launching an IPython kernel.
# ObjectId('5dc1b4f4d3ee89bda29a7e84')

# %%
# Out:
#         title  year  rated     released  runtime  \
# 0  Green Book  2018  PG-13  16 Nov 2018  130 min
#
#                              genre        director  \
# 0  Biography, Comedy, Drama, Music  Peter Farrelly
#
#                                               writer  \
# 0  Nick Vallelonga, Brian Hayes Currie, Peter Far...
#
#                                               actors  \
# 0  Viggo Mortensen, Mahershala Ali, Linda Cardell...
#
#                                                 plot  \
# 0  A working-class Italian-American bouncer becom...
#
#                             language country  \
# 0  English, Italian, Russian, German     USA
#
#                                               poster  \
# 0  https://m.media-amazon.com/images/M/MV5BYzIzYm...
#
#                                              ratings metascore imdb_rating  \
# 0  {'source': 'Internet Movie Database', 'value':...        69         8.2
#
#   imdb_votes    imdb_id   type response
# ...

# %%
DF
# Out:
#                                                actors  \
# 0   Viggo Mortensen, Mahershala Ali, Linda Cardell...
# 0     Rami Malek, Lucy Boynton, Gwilym Lee, Ben Hardy
# 0   Yalitza Aparicio, Marina de Tavira, Diego Cort...
# 0   Chadwick Boseman, Michael B. Jordan, Lupita Ny...
# 0   Olivia Colman, Rachel Weisz, Emma Delves, Faye...
# 0   Lady Gaga, Bradley Cooper, Sam Elliott, Andrew...
# 0   Christian Bale, Amy Adams, Steve Carell, Sam R...
# 0   Alec Baldwin, John David Washington, Isiah Whi...
# 0   Ryan Gosling, Claire Foy, Jason Clarke, Kyle C...
# 0   KiKi Layne, Stephan James, Regina King, Teyona...
# 0                Sindy Lau, Sharmaine Yeoh, Tim Zhang
# 0   Alex Honnold, Tommy Caldwell, Jimmy Chin, Chey...
# 0          Ajeya, Anita, Gouri Choudari, Shabana Khan
# 0   Jamie Bell, Danielle Macdonald, Daniel Henshal...
# 0   Shameik Moore, Jake Johnson, Hailee Steinfeld,...
# 0   Sally Hawkins, Michael Shannon, Richard Jenkin...
# ...
